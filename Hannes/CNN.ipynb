# %%
import numpy as np 
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os

FAST_RUN = False
IMAGE_WIDTH=125
IMAGE_HEIGHT=125
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3
# Out:
# 2024-02-04 20:48:19.390148: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-04 20:48:19.392411: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-04 20:48:19.418114: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-04 20:48:19.418144: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-04 20:48:19.418785: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-04 20:48:19.422865: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-04 20:48:19.423263: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-04 20:48:19.966581: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Pfade zu den Ordnern
folder_potato = 'photos_reduced/Kartoffel_reduced'
folder_onion = 'photos_reduced/Zwiebel_reduced'
folder_carrot = 'photos_reduced/Karotte_reduced'

# Initialisierung der Listen
categories = []
filenames = []

# Durchlaufen des Kartoffel-Ordners
for filename in os.listdir(folder_potato):
    categories.append(0)  # Kartoffel-Kategorie
    filenames.append(os.path.join(folder_potato, filename))

# Durchlaufen des Zwiebel-Ordners
for filename in os.listdir(folder_onion):
    categories.append(1)  # Zwiebel-Kategorie
    filenames.append(os.path.join(folder_onion, filename))

# Durchlaufen des Karotte-Ordners
for filename in os.listdir(folder_carrot):
    categories.append(2)  # Karotte-Kategorie
    filenames.append(os.path.join(folder_carrot, filename))

# Erstellung des DataFrames
df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# Ausgabe der ersten 5 Einträge des Dataframes
df.head()
# Out:
#                                             filename  category
# 0  photos_reduced/Kartoffel_reduced/Kartoffel (11...         0
# 1  photos_reduced/Kartoffel_reduced/Kartoffel (82...         0
# 2  photos_reduced/Kartoffel_reduced/Kartoffel (48...         0
# 3  photos_reduced/Kartoffel_reduced/Kartoffel (70...         0
# 4  photos_reduced/Kartoffel_reduced/Kartoffel (13...         0

# %%
# Anzeigen der Gesamtzahl der Bilder in den Kategorien 
df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:xlabel='category'>

# %%
# Ersetzen der Integer Werte für die Klasse durch einen String 
df["category"] = df["category"].replace({0: 'potato', 1: 'onion', 2: 'carrot'}) 

# Teilen der Daten in Traingsdaten und Validierungsdaten
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size = 32

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.optimizers import RMSprop

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(3, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

#model.compile(loss='categorical_crossentropy', optimizer=RMSprop(learning_rate=0.0001), metrics=['accuracy'])

#model.compile(loss='categorical_crossentropy', optimizer=RMSprop(lr=0.0001), metrics=['accuracy'])



model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 123, 123, 32)      896
#
#  batch_normalization (Batch  (None, 123, 123, 32)      128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 61, 61, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 61, 61, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 59, 59, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 59, 59, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 29, 29, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 29, 29, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 27, 27, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 27, 27, 128)       512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 13, 13, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 13, 13, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 128)       147584
#
#  batch_normalization_3 (Bat  (None, 11, 11, 128)       512
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 5, 5, 128)         0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 5, 5, 128)         0
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 256)               819456
#
#  batch_normalization_4 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 1063491 (4.06 MB)
# Trainable params: 1062275 (4.05 MB)
# Non-trainable params: 1216 (4.75 KB)
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
#earlystop = EarlyStopping(patience=2)
# learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
#                                             patience=2, 
#                                             verbose=1, 
#                                             factor=0.5, 
#                                             min_lr=0.00001)
                                            
# callbacks = [earlystop, learning_rate_reduction]

# %%
# Anwenden von Data Augmentation

train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    #zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# %%
# laden der Bilder in den Datengenerator
train_generator = train_datagen.flow_from_dataframe(
    train_df,  
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 2645 validated image filenames belonging to 3 classes.

# %%
# Normieren der Bilder für die Validation 
validation_datagen = ImageDataGenerator(rescale=1./255)
# laden der Bilder in den Datengenerator
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 662 validated image filenames belonging to 3 classes.

# %%
# Anzeigen der Bilder nach der Data Augmentation 
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)


plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
# Modelltraining

# epochs = 5
# history = model.fit(
#     train_generator, 
#     epochs=epochs,
#     validation_data=validation_generator,
#     validation_steps=total_validate // batch_size,
#     callbacks=callbacks
# )


epochs = 50
history = model.fit(
    train_generator, 
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate // batch_size,
    steps_per_epoch=total_train // batch_size,
    #callbacks=callbacks
)
# Out:
# Epoch 1/50
# 82/82 [==============================] - 18s 202ms/step - loss: 0.8818 - accuracy: 0.6736 - val_loss: 2.5947 - val_accuracy: 0.3187
# Epoch 2/50
# 82/82 [==============================] - 16s 199ms/step - loss: 0.4445 - accuracy: 0.8285 - val_loss: 2.1153 - val_accuracy: 0.3875
# Epoch 3/50
# 82/82 [==============================] - 16s 199ms/step - loss: 0.3200 - accuracy: 0.8695 - val_loss: 3.0034 - val_accuracy: 0.4812
# Epoch 4/50
# 82/82 [==============================] - 16s 200ms/step - loss: 0.2718 - accuracy: 0.8898 - val_loss: 2.8754 - val_accuracy: 0.5281
# Epoch 5/50
# 82/82 [==============================] - 16s 199ms/step - loss: 0.2318 - accuracy: 0.9104 - val_loss: 3.5821 - val_accuracy: 0.4844
# Epoch 6/50
# 82/82 [==============================] - 17s 201ms/step - loss: 0.1797 - accuracy: 0.9334 - val_loss: 1.6075 - val_accuracy: 0.5813
# Epoch 7/50
# 82/82 [==============================] - 17s 201ms/step - loss: 0.1832 - accuracy: 0.9319 - val_loss: 0.9876 - val_accuracy: 0.7203
# Epoch 8/50
# 82/82 [==============================] - 16s 199ms/step - loss: 0.1408 - accuracy: 0.9445 - val_loss: 0.1376 - val_accuracy: 0.9516
# Epoch 9/50
# 82/82 [==============================] - 16s 200ms/step - loss: 0.1261 - accuracy: 0.9529 - val_loss: 0.2937 - val_accuracy: 0.8859
# Epoch 10/50
# 82/82 [==============================] - 16s 200ms/step - loss: 0.1341 - accuracy: 0.9552 - val_loss: 0.3102 - val_accuracy: 0.9094
# Epoch 11/50
# 82/82 [==============================] - 17s 200ms/step - loss: 0.1182 - accuracy: 0.9591 - val_loss: 1.6059 - val_accuracy: 0.6984
# Epoch 12/50
# 82/82 [==============================] - 16s 200ms/step - loss: 0.0912 - accuracy: 0.9625 - val_loss: 0.3116 - val_accuracy: 0.9031
# Epoch 13/50
# 82/82 [==============================] - 17s 207ms/step - loss: 0.0866 - accuracy: 0.9663 - val_loss: 0.1855 - val_accuracy: 0.9266
# Epoch 14/50
# Epoch 32/50
# 82/82 [==============================] - 23s 277ms/step - loss: 0.0417 - accuracy: 0.9862 - val_loss: 0.0405 - val_accuracy: 0.9891
# Epoch 33/50
# 82/82 [==============================] - 23s 278ms/step - loss: 0.0408 - accuracy: 0.9832 - val_loss: 0.0978 - val_accuracy: 0.9609
# Epoch 34/50
# 82/82 [==============================] - 23s 278ms/step - loss: 0.0424 - accuracy: 0.9858 - val_loss: 0.1971 - val_accuracy: 0.9234
# Epoch 35/50
# 82/82 [==============================] - 23s 279ms/step - loss: 0.0521 - accuracy: 0.9809 - val_loss: 1.0295 - val_accuracy: 0.7859
# Epoch 36/50
# 82/82 [==============================] - 23s 280ms/step - loss: 0.0784 - accuracy: 0.9721 - val_loss: 0.5644 - val_accuracy: 0.8359
# Epoch 37/50
# 82/82 [==============================] - 23s 280ms/step - loss: 0.0571 - accuracy: 0.9816 - val_loss: 2.5290 - val_accuracy: 0.6812
# Epoch 38/50
# 82/82 [==============================] - 23s 279ms/step - loss: 0.0703 - accuracy: 0.9755 - val_loss: 0.1765 - val_accuracy: 0.9297
# Epoch 39/50
# 82/82 [==============================] - 23s 282ms/step - loss: 0.0666 - accuracy: 0.9736 - val_loss: 0.2212 - val_accuracy: 0.9094
# Epoch 40/50
# 82/82 [==============================] - 23s 280ms/step - loss: 0.0560 - accuracy: 0.9820 - val_loss: 2.3716 - val_accuracy: 0.6438
# Epoch 41/50
# 82/82 [==============================] - 23s 284ms/step - loss: 0.0341 - accuracy: 0.9897 - val_loss: 0.0613 - val_accuracy: 0.9781
# Epoch 42/50
# 82/82 [==============================] - 24s 288ms/step - loss: 0.0481 - accuracy: 0.9866 - val_loss: 0.1552 - val_accuracy: 0.9359
# Epoch 43/50
# 82/82 [==============================] - 23s 285ms/step - loss: 0.0307 - accuracy: 0.9893 - val_loss: 0.0349 - val_accuracy: 0.9937
# Epoch 44/50
# 82/82 [==============================] - 23s 283ms/step - loss: 0.0294 - accuracy: 0.9893 - val_loss: 0.0384 - val_accuracy: 0.9937
# Epoch 45/50
# 82/82 [==============================] - 30s 368ms/step - loss: 0.0388 - accuracy: 0.9874 - val_loss: 0.2040 - val_accuracy: 0.9375
# Epoch 46/50
# 82/82 [==============================] - 27s 325ms/step - loss: 0.0356 - accuracy: 0.9855 - val_loss: 1.9959 - val_accuracy: 0.7125
# Epoch 47/50
# 82/82 [==============================] - 28s 337ms/step - loss: 0.0453 - accuracy: 0.9832 - val_loss: 0.2201 - val_accuracy: 0.9156
# Epoch 48/50
# 82/82 [==============================] - 28s 337ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.1485 - val_accuracy: 0.9641
# Epoch 49/50
# 82/82 [==============================] - 27s 330ms/step - loss: 0.0326 - accuracy: 0.9881 - val_loss: 0.6086 - val_accuracy: 0.8547
# Epoch 50/50
# 82/82 [==============================] - 27s 331ms/step - loss: 0.0415 - accuracy: 0.9828 - val_loss: 0.0592 - val_accuracy: 0.9781

# %%
#model.save('vegetable.h5')
model.save('vegetable.keras')

# %%
test_loss, test_accuracy = model.evaluate(validation_generator)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 21/21 [==============================] - 2s 79ms/step - loss: 0.0574 - accuracy: 0.9789
# Test Loss: 0.05744975060224533
# Test Accuracy: 0.9788519740104675

# %%
predictions = model.predict(validation_generator)
# Out:
# 21/21 [==============================] - 2s 77ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from keras.models import load_model

model = load_model(r'vegetable.keras')

# Zufälliges Bild auswählen
index = randint(0, len(validation_generator.filepaths) - 1)
image_path = validation_generator.filepaths[index]

# Bild laden und vorhersagen
img = plt.imread(image_path)
img_array = np.expand_dims(img, axis=0)
prediction = model.predict(img_array)

predicted_class_index = prediction.argmax()
predicted_class_name = list(validation_generator.class_indices.keys())[predicted_class_index]


# Vorhersagen visualisieren
plt.imshow(img)
#plt.title(f'Prediction: {prediction.argmax()}')
plt.title(f'Prediction: {predicted_class_name}')
plt.show()


#0: Kartoffel
#1: Zwiebel
#2: Karotte
# Vorhersagen visualisieren
# Out:
# 1/1 [==============================] - 0s 80ms/step

# %%
top_k_indices = np.argsort(prediction[0])[-5:][::-1]
top_k_classes = top_k_indices
print(f"Top-K Predictions: {top_k_classes}")
# Out:
# Top-K Predictions: [0 2 1]

# %%
import matplotlib.pyplot as plt

# Trainings- und Validierungsloss
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Trainings- und Validierungsgenauigkeit
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Anzahl der Epochen
epochs = range(1, len(train_loss) + 1)

# Loss-Plot
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy-Plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
import os


# Pfad zum Ordner mit den Bildern
folder_path = 'KI_Bilder_Burghart_reduced_gemischt'

# Anzahl der Bilder pro Reihe
images_per_row = 3

# Größe der gesamten Abbildung anpassen
plt.figure(figsize=(30, 30))  # Hier kannst du die Größe nach Bedarf anpassen

# Laden des Modells mit den trainierten Gewichten
model = load_model(r'vegetable.h5')


# Iteriere durch alle Bilder im Ordner
for i, filename in enumerate(os.listdir(folder_path), 1): 
    image_path = os.path.join(folder_path, filename)

    # Bild laden und vorhersagen
    img = plt.imread(image_path)
    img_array = np.array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    prediction = model.predict(img_array)
    prediction = model.predict(img_array)

    predicted_class_index = prediction.argmax()
    predicted_class_name = list(validation_generator.class_indices.keys())[predicted_class_index]

    # Subplot erstellen
    plt.subplot((len(os.listdir(folder_path)) + images_per_row - 1) // images_per_row, images_per_row, i)
    
    # Vorhersagen visualisieren
    plt.imshow(img)
    #plt.title(f'Prediction for {filename}: {prediction.argmax()}')
    plt.title(f'Prediction for {filename}: {predicted_class_name}')

# Layout verbessern
plt.tight_layout()
plt.show()

#0: Kartoffel
#1: Zwiebel
#2: Karotte
# Out:
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
